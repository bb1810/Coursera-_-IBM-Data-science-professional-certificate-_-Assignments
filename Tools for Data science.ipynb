# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __NAME : BHARATH BOMMEEESHWAR__
# <OCCUPATION: STUDENT>

# %% [markdown]
# _i am interested in data science because of the growing demand in the markets for data personnel who is curious about finding answer to various problem through data and so i developed my passionate towards it._

# %% [markdown]
# ### Performing addition operation usings two integers

# %%
88+99
# Out:
# 187

# %% [markdown]
# ### Data roles(Bulletins)
#
# - data analyst
# - data engineer
# - data scientists
#
# ### Programs for data science(Numbered list)
#
# 1.Python
# 2.R
# 3.SQL
#
# ### Hyperlink of IBM WATSON studio
#
# https://www.ibm.com/in-en/watson
